# %%
import pandas as pd

# %%
dataframe = pd.read_csv("Resources/datacleaned.csv")

# %%
dataframe
# Out:
#       Marital status  Course  Daytime/evening attendance  \
# 0                  1       2                           1
# 1                  1      11                           1
# 2                  1       5                           1
# 3                  1      15                           1
# 4                  2       3                           0
# ...              ...     ...                         ...
# 3625               1      15                           1
# 3626               1      15                           1
# 3627               1      12                           1
# 3628               1       9                           1
# 3629               1      15                           1
#
#       Previous qualification  Nacionality  Mother's qualification  \
# 0                          1            1                      13
# 1                          1            1                       1
# 2                          1            1                      22
# 3                          1            1                      23
# 4                          1            1                      22
# ...                      ...          ...                     ...
# 3625                       1            1                       1
# 3626                       1           19                       1
# 3627                       1            1                      22
# 3628                       1            1                      22
# 3629                       1            9                      23
#
#       Father's qualification  Mother's occupation  Father's occupation  \
# 0                         10                    6                   10
# 1                          3                    4                    4
# 2                         27                   10                   10
# 3                         27                    6                    4
# 4                         28                   10                   10
# ...                      ...                  ...                  ...
# 3625                       1                    6                    5
# 3626                       1                   10                   10
# 3627                      27                   10                   10
# 3628                      27                    8                    5
# 3629                      27                    6                   10
#
#       Displaced  ...  Curricular units 2nd sem (credited)  \
# 0             1  ...                                    0
# 1             1  ...                                    0
# 2             1  ...                                    0
# 3             1  ...                                    0
# 4             0  ...                                    0
# ...         ...  ...                                  ...
# 3625          0  ...                                    0
# 3626          1  ...                                    0
# 3627          1  ...                                    0
# 3628          1  ...                                    0
# 3629          1  ...                                    0
#
#       Curricular units 2nd sem (enrolled)  \
# 0                                       0
# 1                                       6
# 2                                       6
# 3                                       6
# 4                                       6
# ...                                   ...
# 3625                                    6
# 3626                                    6
# 3627                                    8
# 3628                                    5
# 3629                                    6
#
#       Curricular units 2nd sem (evaluations)  \
# 0                                          0
# 1                                          6
# 2                                          0
# 3                                         10
# 4                                          6
# ...                                      ...
# 3625                                       8
# 3626                                       6
# 3627                                       9
# 3628                                       6
# 3629                                       6
#
#       Curricular units 2nd sem (approved)  Curricular units 2nd sem (grade)  \
# 0                                       0                          0.000000
# 1                                       6                         13.666667
# 2                                       0                          0.000000
# 3                                       5                         12.400000
# 4                                       6                         13.000000
# ...                                   ...                               ...
# 3625                                    5                         12.666667
# 3626                                    2                         11.000000
# 3627                                    1                         13.500000
# 3628                                    5                         12.000000
# 3629                                    6                         13.000000
#
#       Curricular units 2nd sem (without evaluations)  Unemployment rate  \
# 0                                                  0               10.8
# 1                                                  0               13.9
# 2                                                  0               10.8
# 3                                                  0                9.4
# 4                                                  0               13.9
# ...                                              ...                ...
# 3625                                               0               15.5
# 3626                                               0               11.1
# 3627                                               0               13.9
# 3628                                               0                9.4
# 3629                                               0               12.7
#
#       Inflation rate   GDP    Target
# 0                1.4  1.74   Dropout
# 1               -0.3  0.79  Graduate
# 2                1.4  1.74   Dropout
# 3               -0.8 -3.12  Graduate
# 4               -0.3  0.79  Graduate
# ...              ...   ...       ...
# 3625             2.8 -4.06  Graduate
# 3626             0.6  2.02   Dropout
# 3627            -0.3  0.79   Dropout
# 3628            -0.8 -3.12  Graduate
# 3629             3.7 -1.70  Graduate
#
# [3630 rows x 33 columns]

# %%
column_names_as_rows = pd.Series(dataframe.columns)
column_names_as_rows
# Out:
# 0                                     Marital status
# 1                                             Course
# 2                         Daytime/evening attendance
# 3                             Previous qualification
# 4                                        Nacionality
# 5                             Mother's qualification
# 6                             Father's qualification
# 7                                Mother's occupation
# 8                                Father's occupation
# 9                                          Displaced
# 10                         Educational special needs
# 11                                            Debtor
# 12                           Tuition fees up to date
# 13                                            Gender
# 14                                Scholarship holder
# 15                                 Age at enrollment
# 16                                     International
# 17               Curricular units 1st sem (credited)
# 18               Curricular units 1st sem (enrolled)
# 19            Curricular units 1st sem (evaluations)
# 20               Curricular units 1st sem (approved)
# 21                  Curricular units 1st sem (grade)
# 22    Curricular units 1st sem (without evaluations)
# 23               Curricular units 2nd sem (credited)
# 24               Curricular units 2nd sem (enrolled)
# 25            Curricular units 2nd sem (evaluations)
# 26               Curricular units 2nd sem (approved)
# 27                  Curricular units 2nd sem (grade)
# 28    Curricular units 2nd sem (without evaluations)
# 29                                 Unemployment rate
# 30                                    Inflation rate
# 31                                               GDP
# 32                                            Target
# dtype: object
